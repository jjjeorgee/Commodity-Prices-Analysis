# %%
import pandas as pd
import requests
import os
import re
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Importing the Dataset

# %%
commodity = pd.read_csv('COMMODITY_DATA.csv')

# %% [markdown]
# Assessing The Dataset

# %%
## visual assessment

commodity.head()
# Out:
#          date    WTI      COTTON  NATURAL_GAS  ALL_COMMODITIES      COFFEE  \
# 0  2023-04-01  79.45         NaN         2.16              NaN         NaN
# 1  2023-03-01  73.28   95.391304         2.31       167.438844  222.663913
# 2  2023-02-01  76.83   99.430000         2.38       173.851435  229.506000
# 3  2023-01-01  78.12  100.311364         3.27       181.870767  206.760000
# 4  2022-12-01  76.44  100.886364         5.53       193.367161  210.388636
#
#        SUGAR     ALUMINUM  BRENT        CORN       COPPER       WHEAT
# 0        NaN          NaN  84.64         NaN          NaN         NaN
# 1  20.961739  2296.416957  78.43  284.957405  8856.310870  309.429600
# 2  21.403500  2416.181500  82.59  298.245303  8936.587000  332.412023
# 3  19.943182  2494.900909  82.50  302.839988  9007.346364  320.097045
# 4  20.065000  2398.206818  80.92  302.235405  8371.091364  323.654838

# %%
commodity.tail()
# Out:
#            date  WTI  COTTON  NATURAL_GAS  ALL_COMMODITIES  COFFEE  SUGAR  \
# 515  1980-05-01  NaN     NaN          NaN              NaN     NaN    NaN
# 516  1980-04-01  NaN     NaN          NaN              NaN     NaN    NaN
# 517  1980-03-01  NaN     NaN          NaN              NaN     NaN    NaN
# 518  1980-02-01  NaN     NaN          NaN              NaN     NaN    NaN
# 519  1980-01-01  NaN     NaN          NaN              NaN     NaN    NaN
#
#      ALUMINUM  BRENT  CORN  COPPER  WHEAT
# 515       NaN    NaN   NaN     NaN    NaN
# 516       NaN    NaN   NaN     NaN    NaN
# 517       NaN    NaN   NaN     NaN    NaN
# 518       NaN    NaN   NaN     NaN    NaN
# 519       NaN    NaN   NaN     NaN    NaN

# %% [markdown]
# Noticable issues
# 1. Missing values in a number of columns
# 2. The date format is in reverse

# %%
## programmatic assessment

commodity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             520 non-null    object
#  1   WTI              448 non-null    float64
#  2   COTTON           399 non-null    float64
#  3   NATURAL_GAS      316 non-null    float64
#  4   ALL_COMMODITIES  243 non-null    float64
#  5   COFFEE           399 non-null    float64
#  6   SUGAR            399 non-null    float64
#  7   ALUMINUM         399 non-null    float64
#  8   BRENT            432 non-null    float64
#  9   CORN             399 non-null    float64
#  10  COPPER           399 non-null    float64
#  11  WHEAT            399 non-null    float64
# dtypes: float64(11), object(1)
# memory usage: 48.9+ KB

# %%
commodity.shape
# Out:
# (520, 12)

# %%
commodity[commodity['date'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [date, WTI, COTTON, NATURAL_GAS, ALL_COMMODITIES, COFFEE, SUGAR, ALUMINUM, BRENT, CORN, COPPER, WHEAT]
# Index: []

# %%
commodity.describe()
# Out:
#               WTI      COTTON  NATURAL_GAS  ALL_COMMODITIES      COFFEE  \
# count  448.000000  399.000000   316.000000       243.000000  399.000000
# mean    46.330848   77.229527     4.235949       132.493239  136.677453
# std     29.521292   25.302489     2.162403        38.548472   55.900913
# min     11.350000   37.221739     1.630000        61.887199   50.830000
# 25%     20.025000   59.684999     2.660000       106.420703   91.454775
# 50%     36.745000   74.353996     3.605000       122.779981  129.723500
# 75%     68.397500   86.017433     5.375000       166.324143  165.888886
# max    133.880000  229.667391    13.420000       241.409062  300.477143
#
#             SUGAR     ALUMINUM       BRENT        CORN        COPPER  \
# count  399.000000   399.000000  432.000000  399.000000    399.000000
# mean    13.137825  1811.703660   48.902245  158.152671   4681.354093
# std      5.125401   465.559660   32.935352   67.800980   2641.289167
# ...

# %% [markdown]
# Noticeable issues
# 1. The date column is in the object data-type
# 2. As earlier stated, a number of columns contain NaN values.

# %% [markdown]
# Cleaninf The Dataset

# %%
commodity_clean = commodity.copy()

# %%
## Dataset Contains NaN values
### Define: The Dataset contaoins a number of null values. 
commodity_clean[commodity_clean['ALL_COMMODITIES'].notnull()]
# Out:
#            date    WTI      COTTON  NATURAL_GAS  ALL_COMMODITIES      COFFEE  \
# 1    2023-03-01  73.28   95.391304         2.31       167.438844  222.663913
# 2    2023-02-01  76.83   99.430000         2.38       173.851435  229.506000
# 3    2023-01-01  78.12  100.311364         3.27       181.870767  206.760000
# 4    2022-12-01  76.44  100.886364         5.53       193.367161  210.388636
# 5    2022-11-01  84.37  101.165909         5.45       191.131624  213.718182
# ..          ...    ...         ...          ...              ...         ...
# 239  2003-05-01  28.11   57.802500         5.81        63.065977   66.096818
# 240  2003-04-01  28.17   60.780000         5.26        61.887199   64.692273
# 241  2003-03-01  33.51   61.010000         5.93        65.782768   61.748095
# 242  2003-02-01  35.83   58.552632         7.71        70.229514   66.408500
# 243  2003-01-01  32.95   56.713636         5.43        65.153378   65.383478
#
# ...

# %%
## The question now is, do i want to risk losing half of my dataset, 
#in order to retain the all commodities column?

# %%
# for the first part of this analysis, i will suggest dropping the ALL_COMMODITIES,
# as it contains way too many NaN values and will greatly affect the other columns

commodity_clean = commodity_clean.drop('ALL_COMMODITIES', axis=1)

# %%
commodity_clean.shape
# Out:
# (520, 11)

# %%
commodity_clean = commodity_clean.dropna()

# %%
commodity_clean
# Out:
#            date    WTI      COTTON  NATURAL_GAS      COFFEE      SUGAR  \
# 1    2023-03-01  73.28   95.391304         2.31  222.663913  20.961739
# 2    2023-02-01  76.83   99.430000         2.38  229.506000  21.403500
# 3    2023-01-01  78.12  100.311364         3.27  206.760000  19.943182
# 4    2022-12-01  76.44  100.886364         5.53  210.388636  20.065000
# 5    2022-11-01  84.37  101.165909         5.45  213.718182  19.405909
# ..          ...    ...         ...          ...         ...        ...
# 311  1997-05-01  20.82   79.260002         2.25  265.605909  11.128181
# 312  1997-04-01  19.70   78.824997         2.03  205.440909  11.299091
# 313  1997-03-01  20.97   80.625000         1.89  193.408095  11.141000
# 314  1997-02-01  22.18   80.400002         2.15  166.325500  10.813000
# 315  1997-01-01  25.13   79.769997         3.45  131.233913  10.691905
#
#         ALUMINUM  BRENT        CORN       COPPER       WHEAT
# ...
